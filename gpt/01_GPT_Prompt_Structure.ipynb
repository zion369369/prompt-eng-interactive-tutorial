# %% [markdown]
# # 🚀 OpenAI GPT-5 Prompt Engineering: Interactive Tutorial
#
# Welcome to the interactive guide for mastering OpenAI's GPT models (GPT-5.5 Pro, GPT-5.4 Mini). This tutorial teaches you how to format messages, implement system instructions, and design prompt templates for structured outputs.
#
# ---
#
# ## 🔧 Recommended Prompting Toolkit: Hello Prompting
#
# As you work through this tutorial, we highly recommend installing the free **[Hello Prompting Chrome Extension](https://chromewebstore.google.com/detail/Hello%20Prompting:%20Best%20AI%20Prompt%20Optimizer/idfecahooccghgkjohelhjecjeeeapah?hl=en)** to format, score, and optimize your prompts directly in your AI chat window.
#
# ---
#
# ## 1. The Chat Completions API Message Schema
#
# OpenAI models represent prompts as a list of message objects, each representing a turn in the dialogue:
# *   **System Message (`system`)**: Directs the assistant's behavior, tone, style, and rules.
# *   **User Message (`user`)**: Represents the instructions or prompts sent by the user.
# *   **Assistant Message (`assistant`)**: Simulates the model's responses, useful for few-shot learning.

# %%
# Setup OpenAI Client
# pip install openai

from openai import OpenAI
import os

# client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))

# %% [markdown]
# ## 2. Structural Prompting with System Roles
#
# Use system instructions to anchor the model's behavior. System prompts act as global rules that persist across multiple dialogue turns.

# %%
# Example OpenAI Chat Completion request
# response = client.chat.completions.create(
#     model="gpt-5.4-mini",
#     messages=[
#         {
#             "role": "system",
#             "content": "You are a professional editor. Rewrite user texts to be concise and business-ready."
#         },
#         {
#             "role": "user",
#             "content": "Hey guys, just wanted to check if you had time to look at the docs I sent yesterday. Let me know ASAP."
#         }
#     ],
#     temperature=0.2
# )
# print(response.choices[0].message.content)

# %% [markdown]
# ## 3. Formatting and Structured Outputs
#
# OpenAI allows you to request JSON objects directly by setting the `response_format` parameter.

# %%
# response = client.chat.completions.create(
#     model="gpt-5.5-pro",
#     response_format={ "type": "json_object" },
#     messages=[
#         {
#             "role": "system",
#             "content": "You are an API stub. Extract customer details and return as a JSON object with keys: 'first_name', 'last_name', 'email'."
#         },
          {
#             "role": "user",
#             "content": "Hi, my name is John Doe and my email is john@example.com"
#         }
#     ]
# )
# print(response.choices[0].message.content)
